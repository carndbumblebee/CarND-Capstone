# %%
import sys
import os
import cv2
import csv
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import glob
import numpy as np
import tensorflow as tf

# %%
file_names = glob.glob('site_images_traffic_only\\*.jpg')

# %%
def tl_light_classifier(image):
    width_to_trim = int(image.shape[1] / 3)
    # height_to_trim = int(image.shape[0] / 10)
    height_to_trim = 0
    sub_image = image[height_to_trim:(image.shape[0]-height_to_trim), width_to_trim:(image.shape[1]-width_to_trim)]
    
    G_threshold = (200, 255)
    R_threshold = (200, 255)
    B_threshold = (200, 255)
    
    R = sub_image[:,:,0]
    G = sub_image[:,:,1]
    B = sub_image[:,:,2]
    
    B_binary = np.zeros_like(B)
    B_binary[(B > B_threshold[0]) & (B <= B_threshold[1])] = 1
    
    G_binary = np.zeros_like(G)
    G_binary[(G > G_threshold[0]) & (G <= G_threshold[1])] = 1
    
    R_binary = np.zeros_like(R)
    R_binary[(R > R_threshold[0]) & (R <= R_threshold[1])] = 1
    
    threshold = 0.08
    isRed = (np.sum(R_binary) / R_binary.size) > threshold
    isGreen = (np.sum(G_binary) / G_binary.size) > threshold
    isBlue = (np.sum(B_binary) / B_binary.size) > threshold
    
    top_image = G_binary[0:int(G_binary.shape[0]/2), :]
    bottom_image = G_binary[int(G_binary.shape[0]/2):G_binary.shape[0], :]

    if np.sum(bottom_image) == 0:
        is_edge = True
    elif np.sum(top_image) / np.sum(bottom_image) > 5:
        is_edge = True
    else:
        is_edge = False
    
    if isRed and isGreen and isBlue:
        return (0,255,0)
    elif isRed and isGreen and is_edge:
        return (255,0,0)
    elif isRed and isGreen:
        return (255,255,0)
    elif isRed:
        return (255,0,0)
    elif isGreen:
        return (0,255,0)
    else:
        return (255,255,255)

# %%
MODEL_NAME = '..\\ssd_mobilenet_v1_coco_2017_11_17'
# MODEL_NAME = '..\\faster_rcnn_inception_v2_coco_2017_11_08'

# Path to frozen detection graph. This is the actual model that is used for the object detection.
PATH_TO_CKPT = MODEL_NAME + '\\frozen_inference_graph.pb'

# Load a (frozen) Tensorflow model into memory
detection_graph = tf.Graph()
with detection_graph.as_default():
    od_graph_def = tf.GraphDef()
    with tf.gfile.GFile(PATH_TO_CKPT, 'rb') as fid:
        serialized_graph = fid.read()
        od_graph_def.ParseFromString(serialized_graph)
        tf.import_graph_def(od_graph_def, name='')

    sess = tf.Session(graph=detection_graph)
    # Definite input and output Tensors for detection_graph
    image_tensor = detection_graph.get_tensor_by_name('image_tensor:0')
    # Each box represents a part of the image where a particular object was detected.
    detection_boxes = detection_graph.get_tensor_by_name('detection_boxes:0')
    # Each score represent how level of confidence for each of the objects.
    # Score is shown on the result image, together with the class label.
    detection_scores = detection_graph.get_tensor_by_name('detection_scores:0')
    detection_classes = detection_graph.get_tensor_by_name('detection_classes:0')
    num_detections = detection_graph.get_tensor_by_name('num_detections:0')

# %%
image = cv2.imread(file_names[4])
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Expand dimensions since the model expects images to have shape: [1, None, None, 3]
image_np_expanded = np.expand_dims(image, axis=0)

with detection_graph.as_default():
    (boxes, scores, classes, num) = sess.run(
        [detection_boxes, detection_scores, detection_classes, num_detections],
        feed_dict={image_tensor: image_np_expanded})

boxes = np.squeeze(boxes)
classes = np.squeeze(classes).astype(np.int32)
scores = np.squeeze(scores)

for idx, val in enumerate(classes):
    if val == 10:
        break

if scores[idx] >= 0.01:
    nbox = boxes[idx]

    height = image.shape[0]
    width = image.shape[1]

    box = np.array([nbox[0]*height, nbox[1]*width, nbox[2]*height, nbox[3]*width]).astype(int)
    tl_image = image[box[0]:box[2], box[1]:box[3]].copy()
    
    colour = tl_light_classifier(tl_image)
    
    cv2.rectangle(image, (box[1],box[0]), (box[3],box[2]), colour, 5)
    
    plt.figure
    plt.imshow(image)
    plt.show()
# Out:
# 0
# False

# %%
out_dir = 'site_traffic_light_images_out\\'

for filename in file_names:
    head, tail = os.path.split(filename)
    image = cv2.imread(filename)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    
    # Expand dimensions since the model expects images to have shape: [1, None, None, 3]
    image_np_expanded = np.expand_dims(image, axis=0)

    with detection_graph.as_default():
        (boxes, scores, classes, num) = sess.run(
            [detection_boxes, detection_scores, detection_classes, num_detections],
            feed_dict={image_tensor: image_np_expanded})

    boxes = np.squeeze(boxes)
    classes = np.squeeze(classes).astype(np.int32)
    scores = np.squeeze(scores)

    for idx, val in enumerate(classes):
        if val == 10:
            break

    if scores[idx] >= 0.1:
        nbox = boxes[idx]

        height = image.shape[0]
        width = image.shape[1]

        box = np.array([nbox[0]*height, nbox[1]*width, nbox[2]*height, nbox[3]*width]).astype(int)
        tl_image = image[box[0]:box[2], box[1]:box[3]]

        colour = tl_light_classifier(tl_image)
        
        cv2.rectangle(image, (box[1],box[0]), (box[3],box[2]), colour, 5)
    
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    cv2.imwrite(out_dir + tail, image)
# Out:
# 346
# False
# 344
# False
# 297
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 1
# False
# 0
# False
# 4
# False
# 4
# False
# 2
# False
# 2
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 3
# False
# 1
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 11
# False
# 33
# False
# 20
# False
# 23
# False
# 10
# False
# 11
# False
# 12
# False
# 12
# False
# 17
# False
# 9
# False
# 40
# False
# 18
# False
# 13
# False
# 9
# False
# 12
# False
# 13
# False
# 15
# False
# 17
# False
# 20
# False
# 17
# False
# 22
# False
# 22
# False
# 23
# False
# 26
# False
# 15
# False
# 13
# False
# 22
# False
# 19
# False
# 37
# False
# 37
# False
# 80
# False
# 63
# False
# 94
# False
# 58
# False
# 58
# False
# 50
# False
# 49
# False
# 68
# False
# 48
# False
# 58
# False
# 88
# False
# 44
# False
# 45
# False
# 55
# False
# 47
# False
# 44
# False
# 87
# False
# 85
# False
# 56
# False
# 127
# False
# 112
# False
# 108
# False
# 47
# False
# 31
# False
# 74
# False
# 180
# False
# 383
# True
# 420
# True
# 441
# True
# 446
# True
# 478
# True
# 429
# True
# 438
# True
# 608
# True
# 529
# True
# 542
# True
# 444
# True
# 554
# True
# 568
# True
# 699
# True
# 652
# True
# 627
# True
# 717
# True
# 628
# True
# 547
# True
# 702
# True
# 747
# True
# 883
# True
# 869
# True
# 912
# True
# 978
# True
# 868
# True
# 871
# True
# 941
# True
# 1032
# True
# 1078
# True
# 1151
# True
# 1129
# True
# 1136
# True
# 969
# True
# 1218
# True
# 1100
# True
# 1225
# True
# 1076
# True
# 1240
# True
# 1059
# True
# 1074
# True
# 1265
# True
# 920
# True
# 994
# True
# 759
# True
# 838
# True
# 509
# True
# 612
# True
# 748
# True
# 770
# True
# 753
# True
# 843
# True
# 835
# True
# 1136
# True
# 1159
# True
# 0
# False
# 66
# False
# 109
# False
# 65
# False
# 220
# False
# 80
# False
# 142
# False
# 143
# False
# 147
# False
# 150
# False
# 103
# False
# 136
# False
# 149
# False
# 131
# False
# 135
# False
# 151
# False
# 89
# False
# 112
# False
# 110
# False
# 136
# False
# 128
# False
# 132
# False
# 124
# False
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False
# 0
# False

# %%
image = cv2.imread('site_images_traffic_only\\left0161.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Expand dimensions since the model expects images to have shape: [1, None, None, 3]
image_np_expanded = np.expand_dims(image, axis=0)

with detection_graph.as_default():
    (boxes, scores, classes, num) = sess.run(
        [detection_boxes, detection_scores, detection_classes, num_detections],
        feed_dict={image_tensor: image_np_expanded})

boxes = np.squeeze(boxes)
classes = np.squeeze(classes).astype(np.int32)
scores = np.squeeze(scores)

for idx, val in enumerate(classes):
    if val == 10:
        break

if scores[idx] >= 0.01:
    nbox = boxes[idx]

    height = image.shape[0]
    width = image.shape[1]

    box = np.array([nbox[0]*height, nbox[1]*width, nbox[2]*height, nbox[3]*width]).astype(int)
    tl_image = image[box[0]:box[2], box[1]:box[3]].copy()
    
    colour = tl_light_classifier(tl_image)
    
    cv2.rectangle(image, (box[1],box[0]), (box[3],box[2]), colour, 5)
    
    plt.figure
    plt.imshow(image)
    plt.show()
# Out:
# 628
# True

# %%
width_to_trim = int(tl_image.shape[1] / 3)
# height_to_trim = int(image.shape[0] / 10)
height_to_trim = 0
sub_image = tl_image[height_to_trim:(tl_image.shape[0]-height_to_trim), width_to_trim:(tl_image.shape[1]-width_to_trim)]

# %%
plt.figure()

G_threshold = (200, 255)
R_threshold = (200, 255)
B_threshold = (200, 255)

idx = 0
R = sub_image[:,:,0]
G = sub_image[:,:,1]
B = sub_image[:,:,2]

plt.subplot(1, 3, 1)
B_binary = np.zeros_like(B)
B_binary[(B > B_threshold[0]) & (B <= B_threshold[1])] = 1
plt.imshow(B_binary, cmap='gray')
if (idx == 0):
    plt.title("B")

plt.subplot(1, 3, 2)
G_binary = np.zeros_like(G)
G_binary[(G > G_threshold[0]) & (G <= G_threshold[1])] = 1
plt.imshow(G_binary, cmap='gray')
if (idx == 0):
    plt.title("G")

plt.subplot(1, 3, 3)
R_binary = np.zeros_like(G)
R_binary[(R > R_threshold[0]) & (R <= R_threshold[1])] = 1
plt.imshow(R_binary, cmap='gray')
if (idx == 0):
    plt.title("R")
    
plt.show()

isRed = (np.sum(R_binary) / R_binary.size) > 0.05
isGreen = (np.sum(G_binary) / G_binary.size) > 0.05
isBlue = (np.sum(B_binary) / B_binary.size) > 0.05

print((np.sum(R_binary) / R_binary.size))
print((np.sum(G_binary) / G_binary.size))
# Out:
# 0.373630672926
# 0.245696400626

# %%
top_image = G_binary[0:int(tl_image.shape[0]/2), :]
bottom_image = G_binary[int(tl_image.shape[0]/2):tl_image.shape[0], :]

print(np.sum(top_image))
print(np.sum(bottom_image))

if np.sum(bottom_image) == 0:
    is_centre = True
elif np.sum(top_image) / np.sum(bottom_image) < 5:
    is_centre = True
else:
    is_centre = False

print(is_centre)
# Out:
# 628
# 0
# True
